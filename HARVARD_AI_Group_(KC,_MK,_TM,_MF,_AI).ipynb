# %% [markdown]
# <a href="https://colab.research.google.com/github/allai2007/lip2/blob/main/HARVARD_AI_Group_(KC%2C_MK%2C_TM%2C_MF%2C_AI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
# Import OpenCV package and input image path
import cv2
from google.colab.patches  import cv2_imshow
imagePath = 'input_img.JPG'

# Read the image
img = cv2.imread(imagePath)


# Load the classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Convert the image to grayscale
img = cv2.imread('input_img.JPG')
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

gray_image.shape
(4000, 2667)

# Perform the face detection
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Drawing a bounding box
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Displaying the image
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(3023.5), np.float64(4031.5), np.float64(-0.5))

# %%
# Import OpenCV package and input image path
import cv2
from google.colab.patches  import cv2_imshow
imagePath = 'input_img.jpg'

# Read the image
img = cv2.imread(imagePath)


# Load the classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Convert the image to grayscale
img = cv2.imread('input_img.jpg')
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

gray_image.shape
(4000, 2667)

# Perform the face detection
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Drawing a bounding box
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Displaying the image
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(599.5), np.float64(399.5), np.float64(-0.5))

# %%
import cv2
face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# access the webcam
video_capture = cv2.VideoCapture(0)

# Identifiying faces in videostream
def detect_bounding_box(vid):
    gray_image = cv2.cvtColor(vid, cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray_image, 1.1, 5, minSize=(40, 40))
    for (x, y, w, h) in faces:
        cv2.rectangle(vid, (x, y), (x + w, y + h), (0, 255, 0), 4)
    return faces

# Creating a loop for real-time face detection
while True:
  result, video_frame = video_capture.read()

# read frames from the video
if result is False:
  break

# terminate the loop if the frame is not read successfully
  faces = detect_bounding_box(video_frame)

# apply the function we created to the video frame
  cv2.imshow("My Face Detection Project", video_frame)

# display the processed frame in a window named "My Face Detection Project"

if cv2.waitKey(1) & 0xFF == ord("q"):
  break

video_capture.release()
cv2.destroyAllWindows()
